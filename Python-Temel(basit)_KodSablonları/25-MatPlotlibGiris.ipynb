# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
yasListesi=[10,20,30,40,50,60,70,80]

# %%
kiloListesi=[40,60,65,70,80,90,95,80]

# %%
numpyYasDizim=np.array(yasListesi)
numpyKiloDizim=np.array(kiloListesi)

# %%
numpyYasDizim
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80])

# %%
numpyKiloDizim
# Out:
# array([40, 60, 65, 70, 80, 90, 95, 80])

# %%
plt.plot(numpyYasDizim,numpyKiloDizim,"b")
plt.xlabel("Yas")
plt.ylabel("Kilo")
plt.title("Yas Kilo Grafiği")
#plt.show()
# Out:
# Text(0.5, 1.0, 'Yas Kilo Grafiği')

# %%
numpyArray1=np.linspace(1,10,20)

# %%
numpyArray1
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
numpyArray2=numpyArray1**3

# %%
plt.plot(numpyArray1,numpyArray2,"b*-")

# %%
plt.subplot(1,2,1)##Bir sıra olacak ve 2 grafik olacak . 1. grafikteyim
plt.plot(numpyArray1,numpyArray2,"r--"),
plt.xlabel("Sayı")
plt.ylabel("Küpü")
plt.subplot(1,2,2)##Bir sıra olacak 2 grafik olacak ve 2. grafikteyim
plt.plot(numpyArray2,numpyArray1,"b*-")
plt.xlabel("Küpü")
plt.ylabel("Sayı")

plt.tight_layout()

# %%
benimFigure=plt.figure()
figureAxces=benimFigure.add_axes([0.2,0.2,0.5,0.5])
figureAxces.plot(numpyArray1,numpyArray2,"b--")
figureAxces.set_xlabel("sayı")
figureAxces.set_ylabel("kup")
figureAxces.set_title("Sayı Küp Grafiği")
# Out:
# Text(0.5, 1.0, 'Sayı Küp Grafiği')

# %%
figure2=plt.figure()

eksen1=figure2.add_axes([0.1,0.1,0.9,0.9])
eksen2=figure2.add_axes([0.2,0.4,0.3,0.3])


eksen1.plot(numpyArray1,numpyArray2,"b")
eksen1.set_title("eksen1 grafiği")
eksen1.set_xlabel("eksem1 X")
eksen1.set_ylabel("eksen1 Y")

eksen2.plot(numpyArray2,numpyArray1,"r")
eksen2.set_title("eksen2 grafiği")
eksen2.set_xlabel("eksem2 X")
eksen2.set_ylabel("eksen2 Y")
# Out:
# Text(0, 0.5, 'eksen2 Y')

# %%
(benimFigure,benimEksenler)=plt.subplots(nrows=1,ncols=2)
type(benimEksenler)

for eksen in benimEksenler:
    eksen.plot(numpyArray1,numpyArray2,"r")
    eksen.set_xlabel("X")
    
plt.tight_layout()## grafikler arasında mesafeyi açıp daha güzel görünüm
#benimFigure

# %%
yeniFigure=plt.figure()
#dpi=150

yeniEksen=yeniFigure.add_axes([0.2,0.2,0.8,0.8])

yeniEksen.plot(numpyArray1,numpyArray1**2,label="sayını karesi")
yeniEksen.plot(numpyArray1,numpyArray1**3,label="sayının küpü")
yeniEksen.legend(loc=6)##loc yerini belirtiyo

# %%
yeniFigure.savefig("yeniFigure.png",dpi=200)
